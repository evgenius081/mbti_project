# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
#Variables
data_path = os.path.join('..','data')
img_path = os.path.join('..','static','images')

nt = "#61BED6"
nf = "#A386B4"
sj = "#56AC8A"
sp = "#DFC10C"

colors_d = {
    'ENTP':nt,
    'INTP':nt,
    'INTJ':nt,
    'ENTJ':nt,
    'INFJ':nf,
    'ENFJ':nf,
    'INFP':nf,
    'ENFP':nf,
    'ISFJ':sj,
    'ISTJ':sj,
    'ESTJ':sj,
    'ESFJ':sj,
    'ISFP':sp,
    'ISTP':sp,
    'ESTP':sp,
    'ESFP':sp
    }

# %%
#Pull in csv
mbti = pd.read_csv(os.path.join('..','data','clean_data_3.csv'))

# %%
mbti.columns.tolist()
# Out:
# ['type',
#  'is_Extrovert',
#  'is_Sensing',
#  'is_Thinking',
#  'is_Judging',
#  'posts',
#  'clean_posts',
#  'compound_sentiment',
#  'pos_sentiment',
#  'neg_sentiment',
#  'neu_sentiment',
#  'tag_posts',
#  'tagged_words',
#  'POS_VB_mean',
#  'POS_VB_std',
#  'POS_WP_mean',
#  'POS_WP_std',
#  'POS_MD_mean',
#  'POS_MD_std',
#  'POS_``_mean',
#  'POS_``_std',
#  'POS_(_mean',
#  'POS_(_std',
#  'POS_JJR_mean',
#  'POS_JJR_std',
#  'POS_)_mean',
#  'POS_)_std',
#  'POS_CD_mean',
#  'POS_CD_std',
#  'POS_WP$_mean',
#  'POS_WP$_std',
#  'POS_VBD_mean',
#  'POS_VBD_std',
#  'POS_IN_mean',
#  'POS_IN_std',
#  'POS_$_mean',
#  'POS_$_std',
#  'POS_SYM_mean',
#  'POS_SYM_std',
#  'POS_NNPS_mean',
#  'POS_NNPS_std',
#  'POS_VBG_mean',
#  'POS_VBG_std',
#  'POS_PDT_mean',
#  'POS_PDT_std',
#  'POS_POS_mean',
#  'POS_POS_std',
#  'POS_VBZ_mean',
#  'POS_VBZ_std',
#  'POS_JJS_mean',
#  'POS_JJS_std',
#  'POS_,_mean',
#  'POS_,_std',
#  'POS_CC_mean',
#  'POS_CC_std',
#  'POS_VBP_mean',
#  'POS_VBP_std',
#  'POS_._mean',
#  'POS_._std',
#  'POS_JJ_mean',
#  'POS_JJ_std',
#  'POS_UH_mean',
#  'POS_UH_std',
#  'POS_RBR_mean',
#  'POS_RBR_std',
#  "POS_''_mean",
#  "POS_''_std",
#  'POS_NNS_mean',
#  'POS_NNS_std',
#  'POS_RP_mean',
#  'POS_RP_std',
#  'POS_RBS_mean',
#  'POS_RBS_std',
#  'POS_FW_mean',
#  'POS_FW_std',
#  'POS_:_mean',
#  'POS_:_std',
#  'POS_PRP_mean',
#  'POS_PRP_std',
#  'POS_TO_mean',
#  'POS_TO_std',
#  'POS_WDT_mean',
#  'POS_WDT_std',
#  'POS_PRP$_mean',
#  'POS_PRP$_std',
#  'POS_NNP_mean',
#  'POS_NNP_std',
#  'POS_WRB_mean',
#  'POS_WRB_std',
#  'POS_#_mean',
#  'POS_#_std',
#  'POS_DT_mean',
#  'POS_DT_std',
#  'POS_VBN_mean',
#  'POS_VBN_std',
#  'POS_EX_mean',
#  'POS_EX_std',
#  'POS_LS_mean',
#  'POS_LS_std',
#  'POS_RB_mean',
#  'POS_RB_std',
#  'POS_NN_mean',
#  'POS_NN_std',
#  'ADJ_avg',
#  'ADP_avg',
#  'ADV_avg',
#  'CONJ_avg',
#  'DET_avg',
#  'NOUN_avg',
#  'NUM_avg',
#  'PRT_avg',
#  'PRON_avg',
#  'VERB_avg',
#  '._avg',
#  'X_avg',
#  'qm',
#  'em',
#  'colons',
#  'emojis',
#  'word_count',
#  'unique_words',
#  'post_length_var',
#  'upper',
#  'link_count',
#  'ellipses',
#  'img_count']

# %%
mb = mbti.groupby('type').agg({'type':'count'}).rename(columns={'type':'count'}).sort_values('count',ascending=False)
sorted(colors_d.items(), key=lambda pair: mb.index.tolist().index(pair[0]))
plt.figure(figsize=(10,7))
plt.title("Distribution of Personality Types", fontsize=20)
plt.ylabel("Number of posts", fontsize=15)
plt.bar(mb.index, mb['count'], color=list(colors_d.values()))
plt.savefig(os.path.join(img_path,"type_hist.png"))
plt.show()

# %%
avg_words_type = mbti.groupby('type').agg({'avg_word_ct':'median'})
sorted(colors_d.items(), key=lambda pair: avg_words_type.index.tolist().index(pair[0]))
plt.figure(figsize=(10,7))
plt.title("Average word count per post", fontsize=20)
plt.ylabel("Avg word count", fontsize=15)
plt.bar(avg_words_type.index,avg_words_type['avg_word_ct'], color=list(colors_d.values()))
plt.savefig(os.path.join(img_path,"avg_words.png"))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 avg_words_type = mbti.groupby('type').agg({'avg_word_ct':'median'})
#       2 sorted(colors_d.items(), key=lambda pair: avg_words_type.index.tolist().index(pair[0]))
#       3 plt.figure(figsize=(10,7))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\generic.py:1271, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1268 func = maybe_mangle_lambdas(func)
#    1270 op = GroupByApply(self, func, args, kwargs)
# -> 1271 result = op.agg()
#    1272 if not is_dict_like(func) and result is not None:
#    1273     return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:163, in Apply.agg(self)
#     160     return self.apply_str()
#     162 if is_dict_like(arg):
# --> 163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
#     166     return self.agg_list_like()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:403, in Apply.agg_dict_like(self)
#     400     selected_obj = obj._selected_obj
#     401     selection = obj._selection
# --> 403 arg = self.normalize_dictlike_arg("agg", selected_obj, arg)
#     405 is_groupby = isinstance(obj, (DataFrameGroupBy, SeriesGroupBy))
#     406 context_manager: ContextManager
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:535, in Apply.normalize_dictlike_arg(self, how, obj, func)
#     533     if len(cols) > 0:
#     534         cols_sorted = list(safe_sort(list(cols)))
# --> 535         raise KeyError(f"Column(s) {cols_sorted} do not exist")
#     537 aggregator_types = (list, tuple, dict)
#     539 # if we have a dict of any non-scalars
#     540 # eg. {'A' : ['mean']}, normalize all to
#     541 # be list-likes
#     542 # Cannot use func.values() because arg may be a Series
#
# KeyError: "Column(s) ['avg_word_ct'] do not exist"

# %%
plt.figure(figsize=(10,7))
plt.title("Word Count Histogram", fontsize=20)
plt.ylabel("Number of posts", fontsize=15)
mbti['word_count'].hist(bins=20, color=nt)
plt.savefig(os.path.join(img_path,"word_hist.png"))
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.title("Link Count Histogram", fontsize=20)
plt.ylabel("Number of posts", fontsize=15)
mbti['link_count'].hist(bins=12, color=sj)
plt.savefig(os.path.join(img_path,"link_hist.png"))
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.title("IE Count Histogram", fontsize=20)
plt.ylabel("Number of posts", fontsize=15)
plt.xlabel("Introvert | Extrovert", fontsize=15)
mbti['is_Extrovert'].replace(0,'I').replace(1,'E').hist(bins=3, color=sp)
# plt.savefig(os.path.join(img_path,"link_hist.png"))
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.title("NS Count Histogram", fontsize=20)
plt.ylabel("Number of posts", fontsize=15)
plt.xlabel("Intuitive | Sensor", fontsize=15)
mbti['is_Sensing'].replace(0,'N').replace(1,'S').hist(bins=3, color=nt)
# plt.savefig(os.path.join(img_path,"link_hist.png"))
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.title("FT Count Histogram", fontsize=20)
plt.ylabel("Number of posts", fontsize=15)
plt.xlabel("Feelers | Thinkers", fontsize=15)
mbti['is_Thinking'].replace(0,'F').replace(1,'T').hist(bins=3,color=nf)
# plt.savefig(os.path.join(img_path,"link_hist.png"))
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.title("JP Count Histogram",fontsize=20)
plt.ylabel("Number of posts", fontsize=15)
plt.xlabel("Judgers | Percievers", fontsize=15)
mbti['is_Judging'].replace(0,'P').replace(1,'J').hist(bins=3, color=sj)
# plt.savefig(os.path.join(img_path,"link_hist.png"))
plt.show()

# %% [markdown]
# #### Word Clouds

# %%
fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(20, 20))
fig.subplots_adjust(hspace = .1, wspace=.1)
ax = ax.ravel()

for i, mbti_type in enumerate(mbti["type"].unique()):
        wordcloud_words = " ".join(mbti[mbti["type"]==mbti_type]["clean_post"])
        wordcloud = WordCloud(height=500).generate(wordcloud_words)
        ax[i].imshow(wordcloud, interpolation = 'bilinear')
        ax[i].axis("off")
        ax[i].set_title(mbti_type)

# %% [markdown]
# #### Word Count by Type
